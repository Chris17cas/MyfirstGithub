# %% [markdown]
# <a href="https://colab.research.google.com/github/Chris17cas/MyfirstGithub/blob/main/firtscolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Title

# %%
# @title subtitle

# %% [markdown]
# # Nueva sección

# %% [markdown]
# # Title2
# **texto en negrita**

# %%
# @title italics

# %% [markdown]
# - **test**
# - *italic*
# - <font color='green'>test</font>
# - <ins> Subrayado </ins>

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/VAl7q9dHGwY" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/VAl7q9dHGwY" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %%
# %%html
#
# <ul><h1>hola</h1>
#     <h1>hola2</h1>
#     <h1>hola2</h1>
# </ul>
# Out:
# <ul><h1>hola</h1>
#     <h1>hola2</h1>
#     <h1>hola2</h1>
# </ul>

# %% [markdown]
# # Table

# %% [markdown]
# # Text formating
# # **A simple table**
# |c1|c2|
# |--|--|
# |pr1|pr2|
# |pr3|pr4|
#
# # **Equation**
# For Example *The Pytagoras Theorem*
#
# $ a^2 + b^2= c^2$

# %% [markdown]
# # unordered list
#
#
#
# *   elemento prueba1
# *   elemento prueba2
# *   elemento prueba3

# %% [markdown]
# # ordered list
#
#
# 1.   *Element of list 1*
# 2.   *Element of list 2*
# 3.   *Element of list 3*

# %% [markdown]
# # image
# ![link text](data:image/png;base64,...)

# %% [markdown]
# ![colombia.png](data:image/png;base64,...)

# %% [markdown]
# # video

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/VAl7q9dHGwY" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/VAl7q9dHGwY" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %%
# @title image2
